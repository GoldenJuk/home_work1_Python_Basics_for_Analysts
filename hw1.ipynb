# %% [markdown]
# ## Задача № 1

# %% [markdown]
# *На складе лежат разные фрукты в разном количестве.
# Нужно написать функцию, которая на вход принимает любое количество названий фруктов и их количество, а возвращает общее количество фруктов на складе*

# %%
def total_fruits(**fruits):
    total = 0
    for fruit, quantity in fruits.items():
        total += quantity
    return total

fruits = total_fruits(apricot = 10, lemon = 5, orange = 15)
print(f'Общее количество фруктов на складе = {fruits}')
# Out:
# Общее количество фруктов на складе = 30

# %% [markdown]
# ---

# %% [markdown]
# ## Задача № 2

# %% [markdown]
# *Дан список с затратами на рекламу. Но в данных есть ошибки, некоторые затраты имеют отрицательную величину. Удалите такие значения из списка и посчитайте суммарные затраты
# [100, 125, -90, 345, 655, -1, 0, 200]*
#
# *Используйте list comprehensions*

# %%
advertising_expenses = [100, 125, -90, 345, 655, -1, 0, 200]
advertising_expenses = [i for i in advertising_expenses if i >= 0]
total_expenses = sum(advertising_expenses)
print(f'Суммарные затраты на рекламу = {total_cost}')
# Out:
# Суммарные затраты на рекламу = 1425

# %% [markdown]
# ---

# %% [markdown]
# ## Задача № 3.1

# %% [markdown]
# *Даны два списка.*
#
# *Дата покупки*
#
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
#
# *Суммы покупок по датам*
#
# [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
#
#
# ***Найдите, какая выручка у компании в ноябре***
#
# *Используйте list comprehensions*

# %%
dates = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', 
         '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', 
         '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', 
         '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', 
         '2021-10-26', '2021-12-09']
revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 
           6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]

months = [int(date.split("-")[1]) for date in dates]
#print(months)

revenue_in_November = sum([sale for i, sale in enumerate(revenue) if months[i] == 11])
print(f'Выручка у компании в ноябре = {revenue_in_November}')
# Out:
# Выручка у компании в ноябре = 25098

# %% [markdown]
# ---

# %% [markdown]
# ## Задача № 3.2

# %% [markdown]
# *Даны два списка.*
#
# *Дата покупки*
#
# ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
#
# *Суммы покупок по датам*
#
# [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]
#
#
# ***Найдите выручку компании в зависимости от месяца***
#
# *Для этого напишите функцию, которая на вход принимает список с датами и список с выручкой, а на выходе словарь, где ключи - это месяцы, а значения - это выручка.*
#
# *Используйте аннотирование типов.*

# %%
def company_revenue_by_month(dates: List[str], sales: List[int]) -> Dict[str, int]:
    revenue_dict = {}
    for i, date in enumerate(dates):
        key = date.split("-")[1]
        if key not in revenue_dict:
            revenue_dict[key] = 0
        revenue_dict[key] += sales[i]
    return revenue_dict

dates = ['2021-09-14', '2021-12-15', '2021-09-08', '2021-12-05', '2021-10-09', '2021-09-30', '2021-12-22', '2021-11-29', 
         '2021-12-24', '2021-11-26', '2021-10-27', '2021-12-18', '2021-11-09', '2021-11-23', '2021-09-27', '2021-10-02', 
         '2021-12-27', '2021-09-20', '2021-12-13', '2021-11-01', '2021-11-09', '2021-12-06', '2021-12-08', '2021-10-09', 
         '2021-10-31', '2021-09-30', '2021-11-09', '2021-12-13', '2021-10-26', '2021-12-09']
revenue = [1270, 8413, 9028, 3703, 5739, 4095, 295, 4944, 5723, 3701, 4471, 651, 7037, 4274, 6275, 4988, 6930, 2971, 
           6592, 2004, 2822, 519, 3406, 2732, 5015, 2008, 316, 6333, 5700, 2887]

revenue_dict = company_revenue_by_month(dates, revenue)
print(f'Словарь, где ключи - это месяцы, а значения - это выручка: {revenue_dict}')
# Out:
# Словарь, где ключи - это месяцы, а значения - это выручка: {'09': 25647, '12': 45452, '10': 28645, '11': 25098}
